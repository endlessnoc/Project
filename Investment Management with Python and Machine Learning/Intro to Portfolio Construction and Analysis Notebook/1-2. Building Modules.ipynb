# %% [markdown]
# # Building Modules

# %%
import pandas as pd
import risk_kit as rk

# %%
#These 2 lines of code enable your module to be auto-reloaded by default (Whenever you modify the code in the module file).
# %load_ext autoreload
# %autoreload 2

# %%
returns= rk.get_ffme_returns()

# %%
returns.head()
# Out:
#          Small Cap  Large Cap
# 1926-07    -0.0145     0.0329
# 1926-08     0.0512     0.0370
# 1926-09     0.0093     0.0067
# 1926-10    -0.0484    -0.0243
# 1926-11    -0.0078     0.0270

# %%
rk.drawdown(returns['Small Cap'])['Drawdown']
# Out:
# 1926-07    0.000000
# 1926-08    0.000000
# 1926-09    0.000000
# 1926-10   -0.048400
# 1926-11   -0.055822
#              ...
# 2018-08    0.000000
# 2018-09   -0.016800
# 2018-10   -0.115317
# 2018-11   -0.147608
# 2018-12   -0.278109
# Freq: M, Name: Drawdown, Length: 1110, dtype: float64

# %%
rk.drawdown(returns['Small Cap'])['Drawdown'].min()
# Out:
# -0.8330007793945303

# %%
rk.drawdown(returns['1950':]['Small Cap'])['Drawdown'].min()
# Out:
# -0.7000596091967917
